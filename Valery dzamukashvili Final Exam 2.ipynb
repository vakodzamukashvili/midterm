# %% [markdown]
# Rename the file before submitting, you should change the filename to your first and last name

# %% [markdown]
# # 📝 Python Final Exam (40 Points)

# %% [markdown]
# ## **General Guidelines:**
# - This is a closed-book exam. **Internet searches are NOT allowed!**
# - You must complete **all questions** in this Jupyter Notebook.
# - **Plagiarism is strictly prohibited.** Any identical or highly similar submissions will be flagged.
# - You are only allowed to use functions and concepts that were covered in the lectures. Using any functions or libraries beyond what was taught will result in a deduction of points.
# - The total time for this exam is **3 hours**. Manage your time wisely.
# - Your code should be clear, structured, and follow good programming practices.

# %% [markdown]
# ## **Submission Instructions:**
# - **Explain your thought process before coding** for each question. Include:
#   - Your step-by-step approach to solving the problem.
#   - Any assumptions or constraints.
# - <span style="color:red">**No explanation = 0 score.**</span>
#
# **Example Answer Format:**
# Question: Write a function that sums all even numbers in a list.
#
# Explanation (Before Coding):
# - Define a function to take a list as input.
# - Iterate through the list, checking if each number is even (divisible by 2).
# - Add even numbers to a running sum and return the total.

# %% [markdown]
# ### Melody Archive

# %% [markdown]
# You are a music curator at the "Melody Archive," and your task is to organize and analyze data about the songs in the collection. You will use Python to solve the following challenges, such as categorizing songs by genre, calculating average song lengths, and identifying the most popular artists. </br>
# <span style="color:red">Print the results of each tasks</span>

# %% [markdown]
# ## Problem 1: Data Manipulation and Analysis Using Pandas (13 points)

# %% [markdown]
# This problem evaluates students' proficiency in manipulating and analyzing data using the Pandas library. It encompasses a comprehensive range of essential DataFrame operations.

# %% [markdown]
# 1. **Create a Pandas Series**
#    Generate a Pandas Series containing your personal favorite song titles.
#
# 2. **Create a DataFrame with Artist Information**
#    Using the Series created in Task 1, construct a DataFrame with an additional column named `artist` that includes the corresponding artists for each song.
#
# 3. **Create a DataFrame from a List of Dictionaries**
#    Construct a DataFrame from a list of dictionaries, where each dictionary contains the following keys: `title`, `artist`, `genre`, `year`, `duration`, and `popularity`. Populate this DataFrame with your personal favorite song titles.
#
# 4. **Add a New Column**
#    Introduce a new column of your choice to the DataFrame created in Task 3. Ensure the column is relevant to the songs in the DataFrame.
#
# 5. **Retrieve and Print Specific Columns**
#    From the DataFrame created in Task 3, extract and print the first 10 rows, displaying only the `title` and `genre` columns.
#
# 6. **Filter and Display Specific Rows**
#    Filter the DataFrame to include only rows where the `genre` is "Pop". Print the resulting rows, displaying only the `title` and `artist` columns.
#
# 7. **Retrieve Unique Genre Values**
#    From your DataFrame, extract and print the unique values present in the `genre` column.
#
# 8. **Filter Songs by Release Year**
#    Filter your DataFrame to include only songs released after the year 2000. Print the resulting DataFrame.
#
# 9. **Display DataFrame Information**
#    Use DataFrame functions to display the following information:
#    - Dimensions of the DataFrame
#    - Summary statistics for numerical columns
#    - Mean duration of all songs
#
# 10. **Update the DataFrame**
#     Copy your DataFrame using `df.copy()` and perform the following operations on the new DataFrame:
#     - Sort the DataFrame by `artist` in descending order.
#     - Remove the `popularity` column.
#     - Rename the `title` column to `song_title`.
#
# 11. **Group by Genre and Calculate Average Popularity**
#     Group the DataFrame by `genre` and calculate the average `popularity` for each genre. Print the result.
#
# 12. **Concatenate DataFrames**
#     Concatenate your DataFrame with the provided `additional_songs` DataFrame into a new DataFrame named `full_library`. Print the resulting DataFrame.
#
# 13. **Merge DataFrames**
#     Create another DataFrame containing your song titles and their corresponding ratings. Merge this DataFrame with `full_library` on the `title` column. Print the resulting DataFrame.

# %%
import pandas as pd 

additional_songs = pd.DataFrame({
    "title": ["Hotel California", "Uptown Funk"],
    "artist": ["Eagles", "Mark Ronson ft. Bruno Mars"] ,
    "genre": ["Rock", "Pop"] ,
    "year": [1976, 2014] ,
    "popularity": [94, 97],
    "duration": [391, 270]
})

# %%
# problem 1.1

import pandas as pd

# Creating a Pandas Series with favorite song titles
favorite_songs = pd.Series([
    "Bohemian Rhapsody",
    "California Love",
    "Stairway to Heaven",
    "Imagine",
    "Smells Like Teen Spirit"
])

# Displaying the Series
print(favorite_songs)
# Out:
# 0          Bohemian Rhapsody
# 1            California Love
# 2         Stairway to Heaven
# 3                    Imagine
# 4    Smells Like Teen Spirit
# dtype: object

# %%
#problem 1.2

# Creating a DataFrame with song titles and corresponding artists
favorite_songs_df = pd.DataFrame({
    "Song": favorite_songs,
    "Artist": [
        "Queen",
        "2PAC",
        "Led Zeppelin",
        "John Lennon",
        "Nirvana"
    ]
})

# Displaying the DataFrame
print(favorite_songs_df)
# Out:
#                       Song        Artist
# 0        Bohemian Rhapsody         Queen
# 1          California Love          2PAC
# 2       Stairway to Heaven  Led Zeppelin
# 3                  Imagine   John Lennon
# 4  Smells Like Teen Spirit       Nirvana

# %%
#problem 1.3

import pandas as pd

# Creating a DataFrame from a list of dictionaries
songs_data = [
    {"title": "Bohemian Rhapsody", "artist": "Queen", "genre": "Rock", "year": 1975, "duration": 5.55, "popularity": 98},
    {"title": "California love", "artist": "2PAC", "genre": "Rap", "year": 1990, "duration": 6.30, "popularity": 96},
    {"title": "Stairway to Heaven", "artist": "Led Zeppelin", "genre": "Rock", "year": 1971, "duration": 8.02, "popularity": 97},
    {"title": "Imagine", "artist": "John Lennon", "genre": "Soft Rock", "year": 1971, "duration": 3.03, "popularity": 95},
    {"title": "Smells Like Teen Spirit", "artist": "Nirvana", "genre": "Grunge", "year": 2001, "duration": 5.01, "popularity": 99}
]

# Creating a DataFrame
favorite_songs_df = pd.DataFrame(songs_data)

# Displaying the DataFrame
print(favorite_songs_df)
# Out:
#                      title        artist      genre  year  duration  \
# 0        Bohemian Rhapsody         Queen       Rock  1975      5.55
# 1          California love          2PAC        Rap  1990      6.30
# 2       Stairway to Heaven  Led Zeppelin       Rock  1971      8.02
# 3                  Imagine   John Lennon  Soft Rock  1971      3.03
# 4  Smells Like Teen Spirit       Nirvana     Grunge  2001      5.01
#
#    popularity
# 0          98
# 1          96
# 2          97
# 3          95
# 4          99

# %%
#problem 1.4
# Creating a DataFrame
favorite_songs_df = pd.DataFrame(songs_data)

# Adding a new column 'album' to the DataFrame
favorite_songs_df["album"] = [
    "A Night at the Opera",
    "California",
    "Led Zeppelin IV",
    "Imagine",
    "Nevermind"
]

# Displaying the DataFrame
print(favorite_songs_df)
# Out:
#                      title        artist      genre  year  duration  \
# 0        Bohemian Rhapsody         Queen       Rock  1975      5.55
# 1          California love          2PAC        Rap  1990      6.30
# 2       Stairway to Heaven  Led Zeppelin       Rock  1971      8.02
# 3                  Imagine   John Lennon  Soft Rock  1971      3.03
# 4  Smells Like Teen Spirit       Nirvana     Grunge  2001      5.01
#
#    popularity                 album
# 0          98  A Night at the Opera
# 1          96            California
# 2          97       Led Zeppelin IV
# 3          95               Imagine
# 4          99             Nevermind

# %%
#problem 1.5

# Extracting and printing the first 10 rows of the 'title' and 'genre' columns
print(favorite_songs_df[["title", "genre"]].head(10))
# Out:
#                      title      genre
# 0        Bohemian Rhapsody       Rock
# 1          California love        Rap
# 2       Stairway to Heaven       Rock
# 3                  Imagine  Soft Rock
# 4  Smells Like Teen Spirit     Grunge

# %%
#problem 1.6
# Filtering and displaying only songs with genre 'Pop', showing 'title' and 'artist' columns
pop_songs = favorite_songs_df[favorite_songs_df["genre"] == "Rock"]
print(pop_songs[["title", "artist"]])
# Out:
#                 title        artist
# 0   Bohemian Rhapsody         Queen
# 2  Stairway to Heaven  Led Zeppelin

# %%
#problem 1.7
# Extracting and printing unique values in the 'genre' column
unique_genres = favorite_songs_df["genre"].unique()
print("Unique genres:", unique_genres)
# Out:
# Unique genres: ['Rock' 'Rap' 'Soft Rock' 'Grunge']

# %%
#problem 1.8
# Filtering songs released after the year 2000 and printing the result
songs_after_2000 = favorite_songs_df[favorite_songs_df["year"] > 2000]
print(songs_after_2000)
# Out:
#                      title   artist   genre  year  duration  popularity  \
# 4  Smells Like Teen Spirit  Nirvana  Grunge  2001      5.01          99
#
#        album
# 4  Nevermind

# %%
#problem 1.9
# Displaying DataFrame information
print("DataFrame Dimensions:", favorite_songs_df.shape)
print("\nSummary Statistics:")
print(favorite_songs_df.describe())
print("\nMean Duration of Songs:", favorite_songs_df["duration"].mean())
# Out:
# DataFrame Dimensions: (5, 7)
#
# Summary Statistics:
#               year  duration  popularity
# count     5.000000  5.000000    5.000000
# mean   1981.600000  5.582000   97.000000
# std      13.371612  1.823477    1.581139
# min    1971.000000  3.030000   95.000000
# 25%    1971.000000  5.010000   96.000000
# 50%    1975.000000  5.550000   97.000000
# 75%    1990.000000  6.300000   98.000000
# max    2001.000000  8.020000   99.000000
#
# Mean Duration of Songs: 5.581999999999999

# %%
#problem 1.10

# Copying the DataFrame and performing the operations
df_copy = favorite_songs_df.copy()

# Sorting the DataFrame by 'artist' in descending order
df_copy = df_copy.sort_values(by='artist', ascending=False)

# Removing the 'popularity' column
df_copy = df_copy.drop(columns='popularity')

# Renaming the 'title' column to 'song_title'
df_copy = df_copy.rename(columns={'title': 'song_title'})

# Displaying the updated DataFrame
print(df_copy)
# Out:
#                 song_title        artist      genre  year  duration  \
# 0        Bohemian Rhapsody         Queen       Rock  1975      5.55
# 4  Smells Like Teen Spirit       Nirvana     Grunge  2001      5.01
# 2       Stairway to Heaven  Led Zeppelin       Rock  1971      8.02
# 3                  Imagine   John Lennon  Soft Rock  1971      3.03
# 1          California love          2PAC        Rap  1990      6.30
#
#                   album
# 0  A Night at the Opera
# 4             Nevermind
# 2       Led Zeppelin IV
# 3               Imagine
# 1            California

# %%
#problem 1.11

# Grouping by genre and calculating the average popularity
avg_popularity_by_genre = favorite_songs_df.groupby('genre')['popularity'].mean()

# Printing the result
print(avg_popularity_by_genre)
# Out:
# genre
# Grunge       99.0
# Rap          96.0
# Rock         97.5
# Soft Rock    95.0
# Name: popularity, dtype: float64

# %%
# Problem 1.12
# Concatenating the two DataFrames
full_library = pd.concat([favorite_songs_df, additional_songs], ignore_index=True)

# Displaying the resulting DataFrame
print(full_library)
# Out:
#                      title                      artist      genre  year  \
# 0        Bohemian Rhapsody                       Queen       Rock  1975
# 1          California love                        2PAC        Rap  1990
# 2       Stairway to Heaven                Led Zeppelin       Rock  1971
# 3                  Imagine                 John Lennon  Soft Rock  1971
# 4  Smells Like Teen Spirit                     Nirvana     Grunge  2001
# 5         Hotel California                      Eagles       Rock  1976
# 6              Uptown Funk  Mark Ronson ft. Bruno Mars        Pop  2014
#
#    duration  popularity                 album
# 0      5.55          98  A Night at the Opera
# 1      6.30          96            California
# 2      8.02          97       Led Zeppelin IV
# 3      3.03          95               Imagine
# 4      5.01          99             Nevermind
# 5    391.00          94                   NaN
# 6    270.00          97                   NaN

# %%
# Creating a DataFrame with song titles and their corresponding ratings
ratings_data = pd.DataFrame({
    "title": ["Bohemian Rhapsody", "Hotel California", "Stairway to Heaven", "Imagine", "Smells Like Teen Spirit", "Uptown Funk"],
    "rating": [9.8, 9.6, 9.7, 9.5, 9.9, 9.7]
})

# Merging the DataFrames on the 'title' column
merged_library = pd.merge(full_library, ratings_data, on='title', how='left')

# Displaying the resulting DataFrame
print(merged_library)
# Out:
#                      title                      artist      genre  year  \
# 0        Bohemian Rhapsody                       Queen       Rock  1975
# 1          California love                        2PAC        Rap  1990
# 2       Stairway to Heaven                Led Zeppelin       Rock  1971
# 3                  Imagine                 John Lennon  Soft Rock  1971
# 4  Smells Like Teen Spirit                     Nirvana     Grunge  2001
# 5         Hotel California                      Eagles       Rock  1976
# 6              Uptown Funk  Mark Ronson ft. Bruno Mars        Pop  2014
#
#    duration  popularity                 album  rating
# 0      5.55          98  A Night at the Opera     9.8
# 1      6.30          96            California     NaN
# 2      8.02          97       Led Zeppelin IV     9.7
# 3      3.03          95               Imagine     9.5
# 4      5.01          99             Nevermind     9.9
# 5    391.00          94                   NaN     9.6
# 6    270.00          97                   NaN     9.7

# %% [markdown]
# ## Problem 2: Data Visualization (7 points)

# %% [markdown]
# This problem evaluates students' ability to create and customize visualizations using Matplotlib and Seaborn. The tasks focus on generating various types of plots to analyze and present data effectively.

# %% [markdown]
# 1. **Line Chart: Popularity  of Songs per Genre**
#    Create a line chart to display the average popularity of songs in each genre. You can use the result of the task 11 from previous problem. Ensure the plot includes a title, x-label, and y-label.
#
# 2. **Bar Chart: Number of Songs per Genre**
#    Create a bar chart using Matplotlib to visualize the number of songs in each genre. Use the `genre` column for the x-axis and the count of songs for the y-axis. Add a title, x-label, and y-label to the plot.
#
# 3. **Histogram: Distribution of Song Durations**
#    Create a histogram to visualize the distribution of song durations. Use the `duration` column and set the number of bins. Include a title, x-label, and y-label in the plot.
#
# 4. **Scatter Plot: Song Duration vs. Popularity**
#    Create a scatter plot to explore the relationship between song duration and popularity. Add a title, x-label, and y-label to the plot.
#
# 5. **Pie Chart: Percentage of Songs per Genre**
#    Create a pie chart to show the percentage of songs in each genre. Use the `genre` column to group the data. Include a title and labels for each genre in the plot.
#
# 6. **Heatmap: Popularity of Songs by Artist**
#    Using Seaborn, create a heatmap to visualize the popularity of songs by each artist.  Add a title to the plot. You can use the following line to prepare data for plotting: </br>
#    `df.pivot(index='title', columns='artist', values='popularity')`
#
# 7. **Customize a Plot**
#    Choose any plot from Tasks 1–6 and customize it by:
#    - Changing the color scheme.
#    - Adding a grid.
#    - Adjusting the figure size.
#    - Adding annotations (e.g., highlighting the most popular song).
#    - Choose any other parameters of your choice to change

# %%
#problem 2.1

import matplotlib.pyplot as plt

# Grouping the DataFrame by 'genre' and calculating the average popularity
genre_popularity = full_library.groupby('genre')['popularity'].mean()

# Creating the line chart
plt.figure(figsize=(10, 6))
genre_popularity.plot(kind='line', marker='o', color='b')

# Adding title and labels
plt.title('Average Popularity of Songs per Genre', fontsize=16)
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Average Popularity', fontsize=12)

# Displaying the plot
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
#problem 2.2

import matplotlib.pyplot as plt

# Grouping the DataFrame by 'genre' and counting the number of songs in each genre
genre_count = full_library['genre'].value_counts()

# Creating the bar chart
plt.figure(figsize=(10, 6))
genre_count.plot(kind='bar', color='skyblue')

# Adding title and labels
plt.title('Number of Songs per Genre', fontsize=16)
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Number of Songs', fontsize=12)

# Displaying the plot
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
#problem 2.3
import matplotlib.pyplot as plt

# Creating the histogram for song durations
plt.figure(figsize=(10, 6))
plt.hist(full_library['duration'], bins=10, color='lightcoral', edgecolor='black')

# Adding title and labels
plt.title('Distribution of Song Durations', fontsize=16)
plt.xlabel('Duration (minutes)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Displaying the plot
plt.tight_layout()
plt.show()

# %%
#problem 2.4

import matplotlib.pyplot as plt

# Creating the scatter plot for song duration vs. popularity
plt.figure(figsize=(10, 6))
plt.scatter(full_library['duration'], full_library['popularity'], color='green', alpha=0.7)

# Adding title and labels
plt.title('Song Duration vs. Popularity', fontsize=16)
plt.xlabel('Duration (minutes)', fontsize=12)
plt.ylabel('Popularity', fontsize=12)

# Displaying the plot
plt.tight_layout()
plt.show()

# %%
#problem 2.5

import matplotlib.pyplot as plt

# Grouping the data by 'genre' and calculating the percentage of songs in each genre
genre_percentage = full_library['genre'].value_counts()

# Creating the pie chart
plt.figure(figsize=(8, 8))
plt.pie(genre_percentage, labels=genre_percentage.index, autopct='%1.1f%%', colors=['skyblue', 'lightcoral', 'yellowgreen', 'orange', 'gold'], startangle=140)

# Adding a title
plt.title('Percentage of Songs per Genre', fontsize=16)

# Displaying the plot
plt.tight_layout()
plt.show()

# %%
#problem 2.6

import seaborn as sns
import matplotlib.pyplot as plt

# Pivot the data to prepare it for the heatmap
heatmap_data = full_library.pivot(index='title', columns='artist', values='popularity')

# Creating the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', cbar_kws={'label': 'Popularity'}, fmt='.1f')

# Adding a title
plt.title('Popularity of Songs by Artist', fontsize=16)

# Displaying the plot
plt.tight_layout()
plt.show()

# %%
#problem 2.7

import matplotlib.pyplot as plt

# Grouping the DataFrame by 'genre' and counting the number of songs in each genre
genre_count = full_library['genre'].value_counts()

# Creating the bar chart with customizations
plt.figure(figsize=(12, 7))  # Adjusting figure size
bars = plt.bar(genre_count.index, genre_count, color=['lightblue', 'lightgreen', 'salmon', 'orange', 'purple'], edgecolor='black')

# Adding title and labels
plt.title('Number of Songs per Genre', fontsize=18)
plt.xlabel('Genre', fontsize=14)
plt.ylabel('Number of Songs', fontsize=14)

# Adding grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Annotating the most popular genre (the one with the highest count)
most_popular_genre = genre_count.idxmax()
most_popular_value = genre_count.max()
plt.text(most_popular_genre, most_popular_value + 0.2, f'{most_popular_value} Songs', ha='center', fontsize=12, color='black', fontweight='bold')

# Adjusting x-tick labels for better readability
plt.xticks(rotation=45, ha='right')

# Displaying the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Problem 3: Missing Data (10 points)

# %% [markdown]
# This section outlines tasks related to introducing, identifying, and handling missing values in a DataFrame. The tasks are designed to evaluate your ability to manipulate and clean data effectively.

# %%
# Introduce Missing values in Data
def introduce_missing_values(df, missing_fraction=0.5):
    np.random.seed(42)
    total_elements = df.size
    num_missing = int(total_elements * missing_fraction)
    indices = [(row, col) for row in range(df.shape[0]) for col in range(df.shape[1])]
    missing_indices = np.random.choice(len(indices), num_missing, replace=False)
    
    for i in missing_indices:
        row, col = indices[i]
        df.iat[row, col] = np.nan
    return df

# %% [markdown]
# Using the function provided above, apply it to the full_library DataFrame that you created in the first problem. Use result DataFrame to perform the following tasks

# %%
import numpy as np

# Introduce missing values with the given fraction (e.g., 50%)
def introduce_missing_values(df, missing_fraction=0.5):
    np.random.seed(42)
    total_elements = df.size
    num_missing = int(total_elements * missing_fraction)
    indices = [(row, col) for row in range(df.shape[0]) for col in range(df.shape[1])]
    missing_indices = np.random.choice(len(indices), num_missing, replace=False)
    
    for i in missing_indices:
        row, col = indices[i]
        df.iat[row, col] = np.nan
    return df

# Applying the function to the full_library DataFrame
full_library_with_missing = introduce_missing_values(full_library.copy(), missing_fraction=0.5)

# Display the DataFrame with missing values
print(full_library_with_missing)
# Out:
#                      title                      artist      genre    year  \
# 0        Bohemian Rhapsody                       Queen       Rock     NaN
# 1          California love                         NaN        NaN  1990.0
# 2       Stairway to Heaven                         NaN        NaN     NaN
# 3                  Imagine                 John Lennon  Soft Rock     NaN
# 4  Smells Like Teen Spirit                     Nirvana     Grunge     NaN
# 5         Hotel California                      Eagles       Rock  1976.0
# 6              Uptown Funk  Mark Ronson ft. Bruno Mars        NaN     NaN
#
#    duration  popularity            album
# 0       NaN        98.0              NaN
# 1      6.30         NaN              NaN
# 2      8.02         NaN  Led Zeppelin IV
# 3       NaN         NaN              NaN
# 4      5.01         NaN              NaN
# 5    391.00         NaN              NaN
# 6       NaN         NaN              NaN

# %% [markdown]
# 1. **Introduce Missing Values**
#    Introduce missing values into your DataFrame by assigning `None` to some values in specific columns.
#
# 2. **Check for Missing Values**
#    Check if there are any missing values in your chosen column in the DataFrame.
#
# 3. **Check for Missing Values in the Entire DataFrame**
#    Check if there are any missing values present anywhere in the entire DataFrame.
#
# 4. **Count Missing Values per Column**
#    Count the number of missing values in each column of the DataFrame.
#
# 5. **Replace Missing Values with Mean**
#    Given the DataFrame, replace the missing values in the `duration` column with the mean value of that column.
#
# 6. **Replace Missing Values with Median**
#    Using the same DataFrame, replace the missing values in the `popularity` column with the median value of that column.
#
# 7. **Replace Missing Values with a Default String**
#    Given the DataFrame, replace all missing values in the `genre` column with the string `'Missing'`.
#
# 8. **Drop Rows with Missing Values**
#    Identify and remove rows where the `artist` column contains missing values, and print the rows that were dropped as part of this operation.
#
# 9. **Backward Fill Missing Values**
#    Using the same DataFrame, apply method to backward fill the missing values in the `year` column.
#
# 10. **Identifying Missing Values in Everyday Scenarios**  </br>
#    Provide three examples from your personal experiences or observations where missing or incomplete data occurs. Explain the context briefly and highlight how the absence of data impacts the situation.

# %%
# Introduce missing values manually into specific columns of the DataFrame
full_library_with_none = full_library.copy()

# Assign None to some values in specific columns
full_library_with_none.loc[1, 'genre'] = None  # Missing value in 'genre' column
full_library_with_none.loc[3, 'popularity'] = None  # Missing value in 'popularity' column
full_library_with_none.loc[5, 'duration'] = None  # Missing value in 'duration' column

# Display the DataFrame with missing values
print(full_library_with_none)
# Out:
#                      title                      artist      genre  year  \
# 0        Bohemian Rhapsody                       Queen       Rock  1975
# 1          California love                        2PAC       None  1990
# 2       Stairway to Heaven                Led Zeppelin       Rock  1971
# 3                  Imagine                 John Lennon  Soft Rock  1971
# 4  Smells Like Teen Spirit                     Nirvana     Grunge  2001
# 5         Hotel California                      Eagles       Rock  1976
# 6              Uptown Funk  Mark Ronson ft. Bruno Mars        Pop  2014
#
#    duration  popularity                 album
# 0      5.55        98.0  A Night at the Opera
# 1      6.30        96.0            California
# 2      8.02        97.0       Led Zeppelin IV
# 3      3.03         NaN               Imagine
# 4      5.01        99.0             Nevermind
# 5       NaN        94.0                   NaN
# 6    270.00        97.0                   NaN

# %% [markdown]
# ## Problem 4: Data Analysis (10 points)

# %% [markdown]
# This section outlines a series of tasks designed to analyze, manipulate, and clean data in a DataFrame. The tasks focus on calculating statistics, grouping data, identifying outliers, generating random data, and cleaning text columns.

# %% [markdown]
# 1. **Calculate Basic Statistics**
#    Compute basic statistics (mean, median, standard deviation, etc.) for the `popularity` column. Using either NumPy, Statistics or Pandas library
#
# 2. **Group Data and Calculate Max Popularity**
#    Group the data by the `genre` column and calculate the max `duration` for each group.
#
# 3. **Calculate Mean, Count, and Sum by Genre**
#     For each unique genre in the `genre` column, calculate the mean, count, and sum of the `popularity` values.
#
# 4. **Create a Boxplot for Outlier Visualization**
#    Generate a boxplot for the `duration` column to visually identify outliers. Write the data points that are classified as outliers to a new DataFrame or output them for review.
#
# 5. **Create a Scatter Plot for Outlier Visualization**
#    Create a scatter plot of `year` vs. `popularity` to visually identify outliers. Write the data points that are classified as outliers to a new DataFrame or output them for review.
#
# 6. **Find and Remove Duplicate Rows**
#     Identify and print the number of duplicate rows in the DataFrame, then remove them to retain only unique entries.
#
# 7. **Find Unique Values in the Genre Column**
#    Extract and display all unique values in the `artist` column.
#
# 8. **Clean the Column**
#    Clean one of the object type column by converting all values to lowercase and removing any extra spaces.
#
# 9. **Replace a Value in a Column**
#     Select a column of your choice and replace one of its existing values with a new value of your specification.
#
# 10. **Clean the Title Column**
#    Remove any extra spaces or symbols (e.g., `!`, `?`, `.`) from the `title` column.

# %%
import pandas as pd

# Compute basic statistics using pandas
mean_popularity = full_library['popularity'].mean()
median_popularity = full_library['popularity'].median()
std_popularity = full_library['popularity'].std()
min_popularity = full_library['popularity'].min()
max_popularity = full_library['popularity'].max()

# Display the results
print(f"Mean Popularity: {mean_popularity}")
print(f"Median Popularity: {median_popularity}")
print(f"Standard Deviation of Popularity: {std_popularity}")
print(f"Minimum Popularity: {min_popularity}")
print(f"Maximum Popularity: {max_popularity}")

# Alternatively, using describe() for a quick summary
print("\nSummary Statistics using describe():")
print(full_library['popularity'].describe())
# Out:
# Mean Popularity: 96.57142857142857
# Median Popularity: 97.0
# Standard Deviation of Popularity: 1.7182493859684491
# Minimum Popularity: 94
# Maximum Popularity: 99
#
# Summary Statistics using describe():
# count     7.000000
# mean     96.571429
# std       1.718249
# min      94.000000
# 25%      95.500000
# 50%      97.000000
# 75%      97.500000
# max      99.000000
# Name: popularity, dtype: float64
